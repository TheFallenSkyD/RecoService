# %%
import ast
import json
import logging
import os
import pickle
import time
import warnings
from collections import Counter
from logging import getLogger
from pathlib import Path
from random import randint, random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from recbole.config import Config
from recbole.data import create_dataset, data_preparation
from recbole.data.interaction import Interaction
from recbole.model.general_recommender.multivae import MultiVAE
from recbole.model.sequential_recommender import Caser, GRU4Rec
from recbole.quick_start import run_recbole
from recbole.trainer import Trainer
from recbole.utils import init_logger, init_seed
from scipy.sparse import coo_matrix, hstack
from sklearn.metrics.pairwise import (
    cosine_distances,
    cosine_similarity,
    euclidean_distances,
)

# %% [markdown]
# # Загрузка данных

# %%
users_df = pd.read_csv("../datasets/users.csv")
items_df = pd.read_csv("../datasets/items.csv")
interactions_df = pd.read_csv("../datasets/interactions.csv")

# %%
interactions_df["t_dat"] = pd.to_datetime(interactions_df["last_watch_dt"], format="%Y-%m-%d")
interactions_df["timestamp"] = interactions_df.t_dat.values.astype(np.int64) // 10**9

# %%
df = interactions_df[["user_id", "item_id", "timestamp"]].rename(
    columns={"user_id": "user_id:token", "item_id": "item_id:token", "timestamp": "timestamp:float"}
)

# %%
# !mkdir recbox_data

# %%
df.to_csv("recbox_data/recbox_data.inter", index=False, sep="\t")

# %% [markdown]
# # Пайплайн обучения

# %% [markdown]
# ## Создание и разделение датасета

# %%
parameter_dict = {
    "data_path": "",
    "USER_ID_FIELD": "user_id",
    "ITEM_ID_FIELD": "item_id",
    "TIME_FIELD": "timestamp",
    "device": "GPU",
    "user_inter_num_interval": "[40,inf)",
    "item_inter_num_interval": "[40,inf)",
    "load_col": {"inter": ["user_id", "item_id", "timestamp"]},
    "neg_sampling": None,
    "epochs": 40,
    "eval_args": {"split": {"RS": [9, 0, 1]}, "group_by": "user", "order": "TO", "mode": "full"},
}
config = Config(model="MultiVAE", dataset="recbox_data", config_dict=parameter_dict)

# init random seed
init_seed(config["seed"], config["reproducibility"])

# logger initialization
init_logger(config)
logger = getLogger()
# Create handlers
c_handler = logging.StreamHandler()
c_handler.setLevel(logging.INFO)
logger.addHandler(c_handler)

# write config info into log
# logger.info(config)

# %%
dataset = create_dataset(config)
logger.info(dataset)
# Out:
# 13 Dec 12:57    INFO  recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']

# %%
# dataset splitting
train_data, valid_data, test_data = data_preparation(config, dataset)
# Out:
# 13 Dec 12:57    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 13 Dec 12:57    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]

# %% [markdown]
# ## Эксперименты

# %%
# %%time
model_list = ["MultiVAE", "MultiDAE", "MacridVAE", "NeuMF", "RecVAE"]

for model_name in model_list:
    print(f"running {model_name}...")
    start = time.time()
    result = run_recbole(model=model_name, dataset="recbox_data", config_dict=parameter_dict)
    t = time.time() - start
    print(f"It took {t/60:.2f} mins")
    print(result)
# Out:
# running MultiVAE...
# 13 Dec 12:57    INFO  ['C:\\Users\\Happy\\AppData\\Local\\pypoetry\\Cache\\virtualenvs\\recoservice-Q0zB1aiD-py3.10\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Happy\\AppData\\Roaming\\jupyter\\runtime\\kernel-50f90226-56ac-497b-b7da-0b7e76a69b49.json']
# ['C:\\Users\\Happy\\AppData\\Local\\pypoetry\\Cache\\virtualenvs\\recoservice-Q0zB1aiD-py3.10\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Happy\\AppData\\Roaming\\jupyter\\runtime\\kernel-50f90226-56ac-497b-b7da-0b7e76a69b49.json']
# 13 Dec 12:57    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 40
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 40
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 13 Dec 12:57    INFO  recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 13 Dec 12:57    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 13 Dec 12:57    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 13 Dec 12:57    WARNING  Max value of user's history interaction records has reached 20.9471766848816% of the total.
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# 13 Dec 12:57    INFO  MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# 13 Dec 12:57    INFO  FLOPs: 4068000.0
# FLOPs: 4068000.0
# Train     0:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:00,  6.59it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00, 10.94it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:00<00:00, 12.41it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.04it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 12.70it/s]
# 13 Dec 12:57    INFO  epoch 0 training [time: 0.56s, train loss: 3249.5872]
# epoch 0 training [time: 0.56s, train loss: 3249.5872]
# 13 Dec 12:57    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     1:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 13.89it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00, 14.32it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00, 14.49it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 15.07it/s]
# 13 Dec 12:57    INFO  epoch 1 training [time: 0.47s, train loss: 3098.8140]
# epoch 1 training [time: 0.47s, train loss: 3098.8140]
# 13 Dec 12:57    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     2:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 14.25it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00, 14.08it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00, 14.18it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.81it/s]
# 13 Dec 12:57    INFO  epoch 2 training [time: 0.48s, train loss: 3044.8108]
# epoch 2 training [time: 0.48s, train loss: 3044.8108]
# 13 Dec 12:57    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     3:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 14.08it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00, 14.07it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00, 13.94it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.64it/s]
# 13 Dec 12:57    INFO  epoch 3 training [time: 0.48s, train loss: 3006.9387]
# epoch 3 training [time: 0.48s, train loss: 3006.9387]
# 13 Dec 12:57    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     4:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 14.03it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00, 14.14it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00, 14.40it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.95it/s]
# 13 Dec 12:57    INFO  epoch 4 training [time: 0.47s, train loss: 2948.3443]
# epoch 4 training [time: 0.47s, train loss: 2948.3443]
# 13 Dec 12:57    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     5:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 14.29it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00, 14.37it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00, 14.43it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 15.08it/s]
# 13 Dec 12:58    INFO  epoch 5 training [time: 0.47s, train loss: 2916.9971]
# epoch 5 training [time: 0.47s, train loss: 2916.9971]
# 13 Dec 12:58    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     6:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 14.00it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00, 13.62it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00, 13.41it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00, 14.04it/s]
# 13 Dec 12:58    INFO  epoch 6 training [time: 0.50s, train loss: 2897.5956]
# epoch 6 training [time: 0.50s, train loss: 2897.5956]
# 13 Dec 12:58    INFO  Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Saving current: saved\MultiVAE-Dec-13-2023_12-57-57.pth
# Train     7:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00, 12.69it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,
�                     | 6576/13354 [00:03<00:03, 1832.04it/s]:  51%|█████████████████████▊                     | 6760/13354 [00:03<00:03, 1828.96it/s]:  52%|██████████████████████▎                    | 6944/13354 [00:03<00:03, 1826.80it/s]:  53%|██████████████████████▉                    | 7128/13354 [00:03<00:03, 1830.74it/s]:  55%|███████████████████████▌                   | 7313/13354 [00:03<00:03, 1833.49it/s]:  56%|████████████████████████▏                  | 7497/13354 [00:03<00:03, 1823.96it/s]:  58%|████████████████████████▋                  | 7681/13354 [00:04<00:03, 1823.31it/s]:  59%|█████████████████████████▎                 | 7865/13354 [00:04<00:03, 1822.85it/s]:  60%|█████████████████████████▉                 | 8048/13354 [00:04<00:02, 1824.98it/s]:  62%|██████████████████████████▌                | 8231/13354 [00:04<00:02, 1826.48it/s]:  63%|███████████████████████████                | 8414/13354 [00:04<00: ...
# 13 Dec 12:58    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     1.40 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 1.62 G/63.77 G |
# +-------------+----------------+
# The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     1.40 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 1.62 G/63.77 G |
# +-------------+----------------+
# 13 Dec 12:58    INFO  best valid : None
# best valid : None
# 13 Dec 12:58    INFO  test result: OrderedDict([('recall@10', 0.0894), ('mrr@10', 0.1588), ('ndcg@10', 0.0816), ('hit@10', 0.3717), ('precision@10', 0.049)])
# test result: OrderedDict([('recall@10', 0.0894), ('mrr@10', 0.1588), ('ndcg@10', 0.0816), ('hit@10', 0.3717), ('precision@10', 0.049)])
# It took 0.73 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0894), ('mrr@10', 0.1588), ('ndcg@10', 0.0816), ('hit@10', 0.3717), ('precision@10', 0.049)])}
# running MultiDAE...
# 13 Dec 12:58    INFO  ['C:\\Users\\Happy\\AppData\\Local\\pypoetry\\Cache\\virtualenvs\\recoservice-Q0zB1aiD-py3.10\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Happy\\AppData\\Roaming\\jupyter\\runtime\\kernel-50f90226-56ac-497b-b7da-0b7e76a69b49.json']
# ['C:\\Users\\Happy\\AppData\\Local\\pypoetry\\Cache\\virtualenvs\\recoservice-Q0zB1aiD-py3.10\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Happy\\AppData\\Roaming\\jupyter\\runtime\\kernel-50f90226-56ac-497b-b7da-0b7e76a69b49.json']
# 13 Dec 12:58    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 40
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 64
# dropout_prob = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 40
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 64
# dropout_prob = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# ...
# Train    37:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:01,  3.75it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:01,  3.86it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:01,  3.89it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:01<00:00,  3.91it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:01<00:00,  3.90it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:01<00:00,  3.92it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:01<00:00,  4.34it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:01<00:00,  4.06it/s]
# Train    37:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:01,  3.73it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:01,  3.82it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:01,  3.87it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:01<00:00,  3.86it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:01<00:00,  3.88it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:01<00:00,  3.89it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:01<00:00,  4.34it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:01<00:00,  4.04it/s]
# Train    37:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:01,  3.90it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:01,  4.02it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00,  4.05it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,  4.06it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:01<00:00,  4.08it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:01<00:00,  4.08it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:01<00:00,  4.54it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:01<00:00,  4
# %%
result = run_recbole(model="MultiVAE", dataset="recbox_data", config_dict=parameter_dict)
# Out:
# 13 Dec 13:17    INFO  ['C:\\Users\\Happy\\AppData\\Local\\pypoetry\\Cache\\virtualenvs\\recoservice-Q0zB1aiD-py3.10\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Happy\\AppData\\Roaming\\jupyter\\runtime\\kernel-50f90226-56ac-497b-b7da-0b7e76a69b49.json']
# ['C:\\Users\\Happy\\AppData\\Local\\pypoetry\\Cache\\virtualenvs\\recoservice-Q0zB1aiD-py3.10\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Happy\\AppData\\Roaming\\jupyter\\runtime\\kernel-50f90226-56ac-497b-b7da-0b7e76a69b49.json']
# 13 Dec 13:17    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 40
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 40
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 13 Dec 13:18    INFO  recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# 13 Dec 13:18    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 13 Dec 13:18    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 13 Dec 13:18    WARNING  Max value of user's history interaction records has reached 20.9471766848816% of the total.
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# 13 Dec 13:18    INFO  MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# 13 Dec 13:18    INFO  FLOPs: 4068000.0
# FLOPs: 4068000.0
# Train     0:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:00,  7.30it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00,  7.38it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00,  7.35it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,  7.37it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:00<00:00,  7.34it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00,  7.35it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00,  7.73it/s]
# 13 Dec 13:18    INFO  epoch 0 training [time: 0.92s, train loss: 3249.5872]
# epoch 0 training [time: 0.92s, train loss: 3249.5872]
# 13 Dec 13:18    INFO  Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Train     1:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:00,  7.30it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00,  7.33it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00,  7.36it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,  7.36it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:00<00:00,  7.36it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00,  7.37it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00,  7.74it/s]
# 13 Dec 13:18    INFO  epoch 1 training [time: 0.92s, train loss: 3098.8140]
# epoch 1 training [time: 0.92s, train loss: 3098.8140]
# 13 Dec 13:18    INFO  Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Train     2:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:00,  7.30it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00,  7.36it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00,  7.38it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,  7.37it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:00<00:00,  7.36it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00,  7.38it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00,  7.74it/s]
# 13 Dec 13:18    INFO  epoch 2 training [time: 0.92s, train loss: 3044.8108]
# epoch 2 training [time: 0.92s, train loss: 3044.8108]
# 13 Dec 13:18    INFO  Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Train     3:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:00,  7.25it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00,  7.32it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00,  7.36it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,  7.38it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:00<00:00,  7.37it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00,  7.40it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00,  7.75it/s]
# 13 Dec 13:18    INFO  epoch 3 training [time: 0.91s, train loss: 3006.9387]
# epoch 3 training [time: 0.91s, train loss: 3006.9387]
# 13 Dec 13:18    INFO  Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Train     4:   0%|                                                            | 0/7 [00:00<?, ?it/s]:  14%|███████▍                                            | 1/7 [00:00<00:00,  7.30it/s]:  29%|██████████████▊                                     | 2/7 [00:00<00:00,  7.39it/s]:  43%|██████████████████████▎                             | 3/7 [00:00<00:00,  7.36it/s]:  57%|█████████████████████████████▋                      | 4/7 [00:00<00:00,  7.37it/s]:  71%|█████████████████████████████████████▏              | 5/7 [00:00<00:00,  7.38it/s]:  86%|████████████████████████████████████████████▌       | 6/7 [00:00<00:00,  7.39it/s]: 100%|████████████████████████████████████████████████████| 7/7 [00:00<00:00,  7.75it/s]
# 13 Dec 13:18    INFO  epoch 4 training [time: 0.92s, train loss: 2948.3443]
# epoch 4 training [time: 0.92s, train loss: 2948.3443]
# 13 Dec 13:18    INFO  Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
# Saving current: saved\MultiVAE-Dec-13-2023_13-18-17.pth
#
/s]:  17%|███████▍                                   | 2320/13354 [00:02<00:09, 1129.75it/s]:  18%|███████▊                                   | 2433/13354 [00:02<00:09, 1126.46it/s]:  19%|████████▏                                  | 2546/13354 [00:02<00:09, 1124.17it/s]:  20%|████████▌                                  | 2659/13354 [00:02<00:09, 1114.05it/s]:  21%|████████▉                                  | 2771/13354 [00:02<00:09, 1115.81it/s]:  22%|█████████▎                                 | 2883/13354 [00:02<00:09, 1117.06it/s]:  22%|█████████▋                                 | 2995/13354 [00:02<00:09, 1117.93it/s]:  23%|██████████                                 | 3107/13354 [00:02<00:09, 1098.85it/s]:  24%|██████████▎                                | 3217/13354 [00:02<00:09, 1085.98it/s]:  25%|██████████▋                                | 3326/13354 [00:02<00:09, 1083.97it/s]:  26%|███████████                                | 3435/13354 [00:03<00:09, 1082.55it/s]:  27%|███████████▍                               | 3544/13354 [00:03<00:09, 1081.56it/s]:  27%|███████████▊                               | 3653/13354 [00:03<00:09, 1062.01it/s]:  28%|████████████                               | 3760/13354 [00:03<00:09, 1058.14it/s]:  29%|████████████▍                              | 3869/13354 [00:03<00:08, 1064.38it/s]:  30%|████████████▊                              | 3976/13354 [00:03<00:08, 1062.90it/s]:  31%|█████████████▏                             | 4084/13354 [00:03<00:08, 1064.81it/s]:  31%|█████████████▍                             | 4191/13354 [00:03<00:08, 1053.85it/s]:  32%|█████████████▊                             | 4297/13354 [00:03<00:08, 1055.34it/s]:  33%|██████████████▏                            | 4406/13354 [00:03<00:08, 1065.61it/s]:  34%|██████████████▌                            | 4516/13354 [00:04<00:08, 1072.66it/s]:  35%|██████████████▉                            | 4624/13354 [00:04<00:08, 1068.48it/s]:  35%|███████████████▏                           | 4731/13354 [00:04<00:08, 1062.15it/s]:  36%|███████████████▌                           | 4838/13354 [00:04<00:08, 1051.99it/s]:  37%|███████████████▉                           | 4944/13354 [00:04<00: ...
# 13 Dec 13:19    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     3.40 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 2.25 G/63.77 G |
# +-------------+----------------+
# The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     3.40 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 2.25 G/63.77 G |
# +-------------+----------------+
# 13 Dec 13:19    INFO  best valid : None
# best valid : None
# 13 Dec 13:19    INFO  test result: OrderedDict([('recall@10', 0.0894), ('mrr@10', 0.1588), ('ndcg@10', 0.0816), ('hit@10', 0.3717), ('precision@10', 0.049)])
# test result: OrderedDict([('recall@10', 0.0894), ('mrr@10', 0.1588), ('ndcg@10', 0.0816), ('hit@10', 0.3717), ('precision@10', 0.049)])

# %%
result
# Out:
# {'best_valid_score': -inf,
#  'valid_score_bigger': True,
#  'best_valid_result': None,
#  'test_result': OrderedDict([('recall@10', 0.0894),
#               ('mrr@10', 0.1588),
#               ('ndcg@10', 0.0816),
#               ('hit@10', 0.3717),
#               ('precision@10', 0.049)])}

# %%
model = MultiVAE(config, dataset)
checkpoint = torch.load("saved/MultiVAE-Dec-13-2023_12-57-57.pth")
model.load_state_dict(checkpoint["state_dict"])
# Out:
# 13 Dec 13:23    WARNING  Max value of user's history interaction records has reached 23.254401942926535% of the total.
# Max value of user's history interaction records has reached 23.254401942926535% of the total.
# <All keys matched successfully>
